# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import datetime as dt
import glob
import re
import gsw

# %%
trap_metadata = pd.read_csv('../../data_directory/metadata/trap_metadata.csv')
print(trap_metadata)
trap_metadata = trap_metadata[['Deployment', 'Deploy_DateTime_local', 'Recover_DateTime_local']].dropna()
trap_metadata.rename(columns={'Deployment':'deployment',
                              'Deploy_DateTime_local':'deploy_dateTimeAKDT',
                              'Recover_DateTime_local':'recover_dateTimeAKDT'},
                              inplace=True)

trap_metadata['deploy_dateTimeAKDT'] = trap_metadata['deploy_dateTimeAKDT'].apply(lambda x: dt.strptime(x, '%m/%d/%y %H:%M'))
trap_metadata['recover_dateTimeAKDT'] = trap_metadata['recover_dateTimeAKDT'].apply(lambda x: dt.strptime(x, '%m/%d/%y %H:%M'))

# trap_metadata.to_csv('../results/trap_deploy_recover.csv')
# Out:
#    Sample_Number Deployment  Deploy_Station Beacon_Number  \
# 0          T001S       T001              15          D036
# 1          T001D       T001              15          D036
# 2          T002S       T002              16          D036
# 3          T002D       T002              16          D036
# 4          T003S       T003              21          D001
# 5          T003D       T003              21          D001
# 6          T004S       T004              26           480
# 7          T004D       T004              26           480
# 8          T005S       T005              29          6210
# 9          T005D       T005              29          6210
# 10         T006S       T006              32          D036
# 11         T006D       T006              32          D036
# 12         T007S       T007              38          2730
# 13         T007D       T007              38          2730
# 14         T008S       T008              42           130
# 15         T008D       T008              42           130
# 16         T009S       T009              45          8540
# 17         T009D       T009              45          8540
# 18         T010S       T010              48          5130
# 19         T010D       T010              48          5130
# 20         T011S       T011              61          D001
# 21         T011D       T011              61          D001
# 22         T012S       T012              64          D036
# 23         T012D       T012              64          D036
# 24         T013S       T013              67          9430
# 25         T013D       T013              67          9430
# 26         T014S       T014              87          D001
# 27         T014D       T014              87          D001
# 28         T015S       T015              88          7310
# 29         T015D       T015              88          7310
# 30         T016S       T016              92          6210
# 31         T016D       T016              92          6210
# 32         T017S       T017              96          7360
# 33         T017D       T017              96          7360
# 34         T018S       T018             100          D036
# 35         T018D       T018             100          D036
# 36         T019S       T019             121          8540
# 37         T019D       T019             121          8540
# 38         T020S       T020             125           130
# 39         T020D       T020             125           130
# 40         T021S       T021             134          7360
# 41         T021D       T021             134          7360
# 42         T022S       T022             137          D036
# 43         T022D       T022             137          D036
# 44         T023S       T023             157          6210
# 45         T023D       T023             157          6210
# 46         T024S       T024             159          9070
# 47         T024D       T024             159          9070
# 48         T025S       T025             163          9430
# 49         T025D       T025             163          9430
# 50         T026S       T026             174          7360
# 51         T026D       T026             174          7360
# 52         T027S       T027             195          8540
# 53         T027D       T027             195          8540
# 54         T028S       T028             198          6210
# 55         T028D       T028             198          6210
# 56         T029S       T029             207          7360
# 57         T029D       T029             207          7360
#
#     Inclinometer_Number Inclinometer_on_this_trap           Wave_Buoy  \
# 0                4011.0                         F        31100C-Simon
# 1                4011.0                         T        31100C-Simon
# 2                4011.0                         F        31100C-Simon
# 3                4011.0                         T        31100C-Simon
# 4                4814.0                         F    31102C-Garfunkle
# 5                4814.0                         T    31102C-Garfunkle
# 6                4817.0                         T                1708
# 7                4817.0                         F                1708
# 8                4813.0                         T        31100C-Simon
# 9                4813.0                         F        31100C-Simon
# 10               4815.0                         T                 NaN
# 11               4815.0                         F                 NaN
# 12               4812.0                         T                 NaN
# 13               4812.0                         F                 NaN
# 14               4818.0                         T    31102C-Garfunkle
# 15               4818.0                         F    31102C-Garfunkle
# 16               4816.0                         T                1707
# 17               4816.0                         F                1707
# 18               4814.0                         T                1708
# 19               4814.0                         F                1708
# 20               4812.0                         T                 NaN
# 21               4812.0                         F                 NaN
# 22               4813.0                         T                 NaN
# 23               4813.0                         F                 NaN
# 24               4817.0                         T        31100C-Simon
# 25               4817.0                         F        31100C-Simon
# 26               4813.0                         T                 NaN
# 27               4813.0                         F                 NaN
# 28               4812.0                         T    31102C-Garfunkle
# 29               4812.0                         F    31102C-Garfunkle
# 30               4814.0                         T                1707
# 31               4814.0                         F                1707
# 32               4818.0                         T                1708
# 33               4818.0                         F                1708
# 34               4816.0                         T                 NaN
# 35               4816.0                         F                 NaN
# 36                  NaN                         F                 NaN
# 37                  NaN                         F                 NaN
# 38               4817.0                         T              31100C
# 39               4817.0                         F              31100C
# 40               4813.0                         T                1708
# 41               4813.0                         F                1708
# 42               4816.0                         T                 NaN
# 43               4816.0                         F                 NaN
# 44               4812.0                         F                 NaN
# 45               4812.0                         T                 NaN
# 46               4818.0                         T    31102C-Garfunkle
# 47               4818.0                         F    31102C-Garfunkle
# 48               4814.0                         T                1707
# 49               4814.0                         F                1707
# 50               4816.0                         T                1708
# 51               4816.0                         F                1708
# 52               4817.0                         T  2080 backup beacon
# 53               4817.0                         F  2080 backup beacon
# 54               4812.0                         T        31100C-Simon
# 55               4812.0                         F        31100C-Simon
# 56               4816.0                         T                1708
# 57               4816.0                         F                1708
#
#         Deploy_Type                                       Deploy_Team  \
# 0               ice                  James, Gert, Kevin, Lexi, Thomas
# 1               ice                  James, Gert, Kevin, Lexi, Thomas
# 2                ow                                 James, Gert, Lexi
# 3                ow                                 James, Gert, Lexi
# 4               ice  James, Gert, Lexi, Daniel, Thomas, extra helpers
# 5               ice  James, Gert, Lexi, Daniel, Thomas, extra helpers
# 6                ow                                       James, Lexi
# 7                ow                                       James, Lexi
# 8               miz                               James, Matt, Thomas
# 9               miz                               James, Matt, Thomas
# 10              ice                                       James, Lexi
# 11              ice                                       James, Lexi
# 12              ice                                       James, Lexi
# 13              ice                                       James, Lexi
# 14              ice                                       James, Lexi
# 15              ice                                       James, Lexi
# 16              miz                          James, Matt, Thomas, Abi
# 17              miz                          James, Matt, Thomas, Abi
# 18               ow                                      James, Kevin
# 19               ow                                      James, Kevin
# 20              ice                               James, Lexi, Thomas
# 21              ice                               James, Lexi, Thomas
# 22              ice                             James, Lexi, Courtney
# 23              ice                             James, Lexi, Courtney
# 24              miz                                 James, Lexi, Gert
# 25              miz                                  James, Lexi Gert
# 26              ice                             James, Courtney, Lexi
# 27              ice                             James, Courtney, Lexi
# 28  miz - see notes                                James, Kevin, Matt
# 29  miz - see notes                                James, Kevin, Matt
# 30              ice                                       James, Lexi
# 31              ice                                       James, Lexi
# 32               ow                                             James
# 33               ow                                             James
# 34               ow                                             James
# 35               ow                                             James
# 36  miz - see notes                                             James
# 37  miz - see notes                                             James
# 38  miz - see notes                                             James
# 39  miz - see notes                                             James
# 40               ow                                        Lexi, Gert
# 41               ow                                        Lexi, Gert
# 42               ow                                             James
# 43               ow                                             James
# 44              miz                                             James
# 45              miz                                             James
# 46              miz                                        Lexi, Gert
# 47              miz                                        Lexi, Gert
# 48              miz                                             James
# 49              miz                                             James
# 50               ow                                             James
# 51               ow                                             James
# 52              miz                                             James
# 53              miz                                             James
# 54               ow                                       James, Matt
# 55               ow                                       James, Matt
# 56               ow                                       James, Matt
# 57               ow                                       James, Matt
#
#    Deploy_Date_Local  ... Recover_Bottom_Depth Recover_Salinity  \
# 0            6/20/23  ...                 43.0               36
# 1            6/20/23  ...                 43.0             35.8
# 2            6/21/23  ...                  NaN             35.3
# 3            6/21/23  ...                  NaN               35
# 4            6/22/23  ...                 43.3               31
# 5            6/22/23  ...                 43.3             32.7
# 6            6/24/23  ...                  NaN               36
# 7            6/25/23  ...                  NaN               36
# 8            6/24/23  ...                 45.0               35
# 9            6/24/23  ...                 45.0               35
# 10           6/25/23  ...                 44.9             35.6
# 11           6/25/23  ...                 44.9             35.6
# 12           6/27/23  ...                 45.3             37_R
# 13           6/27/23  ...                 45.3             37_R
# 14           6/28/23  ...                 45.0             37_R
# 15           6/28/23  ...                 45.0             37_R
# 16           6/29/23  ...                 42.8             38_R
# 17           6/29/23  ...                 42.8             37_R
# 18           6/29/23  ...                 34.4             37_R
# 19           6/29/23  ...                 34.4             37_R
# 20            7/2/23  ...                 45.0             34_R
# 21            7/2/23  ...                 45.0             36_R
# 22            7/3/23  ...                 45.2             38_R
# 23            7/3/23  ...                 45.2             39_R
# 24            7/4/23  ...                 46.0             40_R
# 25            7/4/23  ...                 46.0             39_R
# 26            7/7/23  ...                 43.9             38_R
# 27            7/7/23  ...                 43.9             36_R
# 28            7/7/23  ...                 45.0             40_R
# 29            7/7/23  ...                 45.0             40_R
# 30            7/8/23  ...                 45.3             35_R
# 31            7/8/23  ...                 45.3             38_R
# 32            7/8/23  ...                 32.8             36_R
# 33            7/8/23  ...                 32.8             37_R
# 34            7/8/23  ...                 43.8             40_R
# 35            7/8/23  ...                 43.8             40_R
# 36           7/11/23  ...                 45.7             38_R
# 37           7/11/23  ...                 45.7             36_R
# 38           7/12/23  ...                 45.0             40_R
# 39           7/12/23  ...                 45.0             39_R
# 40           7/13/23  ...                 44.6              NaN
# 41           7/13/23  ...                 44.6              NaN
# 42           7/13/23  ...                 44.5             34_R
# 43           7/13/23  ...                 44.5             36_R
# 44           7/15/23  ...                 42.9             38_R
# 45           7/15/23  ...                 42.9             36_R
# 46           7/16/23  ...                 46.2             34_R
# 47           7/16/23  ...                 46.2             35_R
# 48           7/16/23  ...                 45.0             35_R
# 49           7/16/23  ...                 45.0             34_R
# 50           7/17/23  ...                 37.5             35_R
# 51           7/17/23  ...                 37.5             37_R
# 52           7/19/23  ...                 44.0             40_R
# 53           7/19/23  ...                 44.0             38_R
# 54           7/20/23  ...                 46.0             40_R
# 55           7/20/23  ...                 46.0             40_R
# 56           7/21/23  ...                 44.0             39_R
# 57           7/21/23  ...                 44.0             37_R
#
#    Recover_Swimmers_Total                              Recover_Swimmers_Type  \
# 0                      na                                                 na
# 1                      na                                                 na
# 2                       3                           2 Chaetonaths, 1 copepod
# 3                       3                                         3 copepods
# 4                       0                                        no swimmers
# 5                       1                                           1 shrimp
# 6                       5         3 chaetognaths, 1 round worm, 1 acorn worm
# 7                       7                       6 Chaetognaths, 1 round worm
# 8                       7          5 chaetognaths, 1 copeod, 1 annelid larva
# 9                       2                         1 copepod, 1 annelid larva
# 10                     11  1 large orange roundworm, 5 large pods, 3 smal...
# 11                      1                                    1 small copepod
# 12                      8    1 large copepod, 1 chaetognath, 6 small copepod
# 13                      1                                    1 small copepod
# 14                     26  3 chaetognaths, 23 small copepods, side note: ...
# 15                      0    no swimmers, just diatoms and scattered debris.
# 16                     10  2 chaetognaths, 3 adult copepods, 3 polychaete...
# 17                      2                   2 polychate larvae (nectochaete)
# 18                    144  2 chaetognaths, 1 small annelid, 1 annelid lar...
# 19                     56  2 chaetognaths, 2 small annelids (polychaetes)...
# 20                      0                                        no swimmers
# 21                      0                                        no swimmers
# 22                      3                                   3 small copepods
# 23                      0                                        no swimmers
# 24                     14  2 chaetognaths, 2 crab larvae, 1 polychaete la...
# 25                      9             1 chaetognath, 8 copepods, some debris
# 26                      0                                        no swimmers
# 27                      1                              mysid shrimp (large!)
# 28                     23              23 copepods, 1 green polychaete larva
# 29                     10                      1 long clear worm, 9 copepods
# 30                      7                          1 chaetognath, 6 copepods
# 31                      5  1 small shrimp, 3 copepods, 1 swimming worm-li...
# 32                     50  2 chaetognaths, 5 swimming stage polychaete la...
# 33                    NaN          15 polychaete larva, hundreds of copepods
# 34                    NaN  ~15 polychaete larvae, 3 snail larvae, 1 larva...
# 35                    NaN  ~31 polychaete larvae, 15 sea cucumber(?) awai...
# 36                      1                                          1 copepod
# 37                      0                                        no swimmers
# 38                     10  1 chaetognath, 8 copepods, 1 swimming polychae...
# 39                      5                    2 copepods, 3 polychaete larvae
# 40                    NaN                                                NaN
# 41                    NaN                                                NaN
# 42                     54  1 large copepod larva, 7 pteropod larvae, ~20 ...
# 43                     52  4 polychaete larvae (10-12 segment), ~40 copep...
# 44                      6         I chaetognath, 4 copepods, 1 annelid larva
# 45                      3  1 nematode, 1 predatory neimole, 1 long string...
# 46                      5                                         5 copepods
# 47                      1                                          1 copepod
# 48                     10                    7 copepods, 3 polychaete larvae
# 49                      2                                         2 copepods
# 50                     30                                     ~30 baby clams
# 51                      9                        8 copepods, 1 annelid larva
# 52                      4  1 nematode, 1 chaetognath, 1 copepod, 1 anneli...
# 53                      1                                          1 copepod
# 54                     29     25 copepods, 1 chaetognath, 3 polychaete larva
# 55                     10                     7 polychaete larva, 3 copepods
# 56                      9  1 ctenophore, 4 polychaete larva, 2 baby clams...
# 57                     20  1 chaetognath, 2 small ctenophores, 6 polychae...
#
#                                 swimmers_type_revised  \
# 0                                                  na
# 1                                                  na
# 2                                                good
# 3                                                good
# 4                                                good
# 5                                                good
# 6                                                good
# 7                                                good
# 8   5 chaetognaths, 1 copeod, 1 polychaete (subset...
# 9             1 copepod, 1 polychaete (annelid) larva
# 10  1 large orange roundworm, 5 large pods, 3 smal...
# 11                                               good
# 12                                               good
# 13                                               good
# 14                                               good
# 15                                               good
# 16                                               good
# 17                                               good
# 18                                               good
# 19                                               good
# 20                                               good
# 21                                               good
# 22                                               good
# 23                                               good
# 24  tiny shrimp flagged as potential mis-ID, but u...
# 25                                               good
# 26                                               good
# 27                                               good
# 28                                               good
# 29                                               good
# 30                                               good
# 31  small shrimp flagged as potential mis-ID.  Sam...
# 32  2 chaetognaths, 5 trochophore (swimming stage ...
# 33                                               good
# 34  ~15 polychaete larvae, 3 snail larvae, 1 larva...
# 35  sea cucumbers still a bit of a mystery, ID is ...
# 36                                               good
# 37                                               good
# 38  1 chaetognath, 8 copepods, 1 trochophore (swim...
# 39                                               good
# 40                                                NaN
# 41                                                NaN
# 42  1 large copepod larva, 7 pteropod larvae, ~20 ...
# 43  4 polychaete larvae (10-12 segment)/nectochate...
# 44      I chaetognath, 4 copepods, 1 polychaete larva
# 45  1 nematode, 1 predatory nematode, 1 long strin...
# 46                                               good
# 47                                               good
# 48                                               good
# 49                                               good
# 50       ~30 pediveliger larval (pre-juvenile)  clams
# 51                      8 copepods, 1 polychate larva
# 52  1 nematode, 1 chaetognath, 1 copepod, 1 polych...
# 53                                               good
# 54                                               good
# 55                                               good
# 56  1 ctenophore, 4 polychaete larva, 2 pedivelige...
# 57  1 chaetognath, 2 small ctenophores, 6 polychae...
#
#     Recovery_total_volume_L  \
# 0                        na
# 1                        na
# 2                       5.6
# 3                      5.59
# 4                       5.4
# 5                       5.5
# 6                       5.4
# 7                       5.4
# 8                       5.5
# 9                       5.4
# 10                     5.58
# 11                     5.52
# 12                     5.62
# 13                     5.54
# 14                     5.62
# 15                     5.64
# 16                     5.64
# 17                      5.6
# 18                     5.44
# 19                      5.3
# 20                        4
# 21                     5.52
# 22                      5.3
# 23                      5.6
# 24                     5.54
# 25                      5.6
# 26                     5.68
# 27                     5.48
# 28                     5.63
# 29                     5.58
# 30                     5.55
# 31                      5.6
# 32                      5.5
# 33                     5.49
# 34                     5.64
# 35                      5.6
# 36                      5.5
# 37                     5.57
# 38                     5.71
# 39                     5.43
# 40                      NaN
# 41                      NaN
# 42                     5.69
# 43                     5.65
# 44                     5.63
# 45                      5.5
# 46                     5.46
# 47                     5.58
# 48                     5.49
# 49                     5.58
# 50                     5.66
# 51                     5.62
# 52                     5.64
# 53                     5.44
# 54                     5.32
# 55                      5.5
# 56                     5.45
# 57                      5.5
#
#                                          Deploy_Notes  \
# 0   Test Deployment - only down for a few minutes....
# 1   Test Deployment - only down for a few minutes....
# 2   Open water deployment with no drogue. Bottom d...
# 3   Open water deployment with no drogue. Bottom d...
# 4   Ice deployment. First hole punch attempt not s...
# 5   Ice deployment. First hole punch attempt not s...
# 6   Deployment very smooth. Drogue attached to wei...
# 7   Deployment very smooth. Drogue attached to wei...
# 8   No Drogue.multiple ice floes present near depl...
# 9   No Drogue.multiple ice floes present near depl...
# 10  Ice deployment. No wave buoy this week. Traps ...
# 11  Ice deployment. No wave buoy this week. Traps ...
# 12  Ice deployment. Secondary beacon (#7310) bolte...
# 13  Ice deployment. Secondary beacon (#7310) bolte...
# 14  Ice Deployment. No secondary beacon. New radar...
# 15  Ice Deployment. No secondary beacon. New radar...
# 16  Open Water Deployment, no drogue because ice p...
# 17  Open Water Deployment, no drogue because ice p...
# 18  Open water deployment without drogue (drogue l...
# 19  Open water deployment without drogue (drogue l...
# 20  Ice deployment. Very smooth process. Drilled i...
# 21  Ice deployment. Very smooth process. Drilled i...
# 22  Ice Much thicker than expected. Greater than 2...
# 23  Ice Much thicker than expected. Greater than 2...
# 24           marginal ice deployment (approx 15% SIC)
# 25           marginal ice deployment (approx 15% SIC)
# 26  0130 on the ice cross. 2 false bottoms and ver...
# 27  0130 on the ice cross. 2 false bottoms and ver...
# 28  Intended ice deployment, but ice was rafted an...
# 29  Intended ice deployment, but ice was rafted an...
# 30  Smooth and easy ice deployment in the fog, not...
# 31  Smooth and easy ice deployment in the fog, not...
# 32                   Uneventful open water deployment
# 33                   Uneventful open water deployment
# 34  Testing beacon buoy in open water. Otherwise u...
# 35  Testing beacon buoy in open water. Otherwise u...
# 36  built another beacon bouy for this deployment....
# 37  built another beacon bouy for this deployment....
# 38    deployment in consildated ice, but in the water
# 39    deployment in consildated ice, but in the water
# 40                   Uneventful open water deployment
# 41                   Uneventful open water deployment
# 42  mast and beacon buoy both attached. No wave bu...
# 43  mast and beacon buoy both attached. No wave bu...
# 44   No mast and only one beacon mounted to trap buoy
# 45   No mast and only one beacon mounted to trap buoy
# 46  no mast and beacon mounted to trap line buoy. ...
# 47  no mast and beacon mounted to trap line buoy. ...
# 48  no mast, wave buoy and beaconed trap line buoy...
# 49  no mast, wave buoy and beaconed trap line buoy...
# 50  sings that hold trap are rusted beyond repair....
# 51  sings that hold trap are rusted beyond repair....
# 52                    trapline beacon and buoy beacon
# 53                    trapline beacon and buoy beacon
# 54  Kept line short despite deep seafloor here as ...
# 55  Kept line short despite deep seafloor here as ...
# 56                                   Final Deployment
# 57                                   Final Deployment
#
#                                         Recover_Notes vol_filtered_L  vol_Flag
# 0   Caught slush from auger hole, see deployment n...            NaN       NaN
# 1   Caught slush from auger hole, see deployment n...            NaN       NaN
# 2   First true recovery!! Might consider brighter ...          0.447       NaN
# 3   First true recovery!! Might consider brighter ...          0.427       NaN
# 4   Sample recovery went perfectly, but weight at ...          0.500       NaN
# 5   Sample recovery went perfectly, but weight at ...          0.100       NaN
# 6   Lost the bottom section of the radar reflector...          0.100         T
# 7   Lost the bottom section of the radar reflector...          0.100         T
# 8                       Almost no ice upon recovery.           0.100         T
# 9                       Almost no ice upon recovery.           0.100         T
# 10  Really easy recovery, both holes open and clea...          0.100       NaN
# 11  Really easy recovery, both holes open and clea...          0.100       NaN
# 12  Chedcked final salinity with refractometer and...          0.100       NaN
# 13  Chedcked final salinity with refractometer and...          0.100       NaN
# 14  Very quick and easy recovery at HRE6 station. ...          0.100       NaN
# 15  Very quick and easy recovery at HRE6 station. ...          0.100       NaN
# 16       no drogue. Small ice floes present (10% SIC)          0.100       NaN
# 17       no drogue. Small ice floes present (10% SIC)          0.100       NaN
# 18  Radar reflector mast lost, believe pole broke ...          0.100         T
# 19  Radar reflector mast lost, believe pole broke ...          0.100         T
# 20  shallow trap spill on recovery. At least one l...          0.100         T
# 21                       deep trap recovery went fine          0.100         T
# 22  Easy recovery, high flier slightly frozen, but...          0.100       NaN
# 23  Easy recovery, high flier slightly frozen, but...          0.100       NaN
# 24  Simple recovery. Lat long is correct here (all...          0.100         T
# 25  Simple recovery. Lat long is correct here (all...          0.100         T
# 26  A polar bear attacked this trap. At the bottom...          0.050       NaN
# 27  A polar bear attacked this trap. At the bottom...          0.050       NaN
# 28  trap recovered sandwiched between two large ic...          0.100       NaN
# 29  trap recovered sandwiched between two large ic...          0.100       NaN
# 30  The ice floe was substantially melted by the t...          0.050       NaN
# 31  The ice floe was substantially melted by the t...          0.050       NaN
# 32  uneventful open water recovery. Gert has a vid...          0.050       NaN
# 33  uneventful open water recovery. Gert has a video.          0.050       NaN
# 34  uneventful open water recovery. TONS of swimme...          0.050       NaN
# 35  uneventful open water recovery. TONS of swimme...          0.050       NaN
# 36               trap was in small floe upon recovery          0.050       NaN
# 37               trap was in small floe upon recovery          0.050       NaN
# 38  heavy ice coverage prevented normal recovery. ...          0.100       NaN
# 39  heavy ice coverage prevented normal recovery. ...          0.100       NaN
# 40  trap line lost. Wire bail at bottom of trap bu...            NaN       NaN
# 41  trap line lost. Wire bail at bottom of trap bu...            NaN       NaN
# 42                                      easy recovery          0.100       NaN
# 43                                      easy recovery          0.100       NaN
# 44  trapline beacon was kind of under ice floe so ...          0.050       NaN
# 45  trapline beacon was kind of under ice floe so ...          0.050       NaN
# 46                                                NaN          0.050       NaN
# 47                                                NaN          0.050       NaN
# 48                     uneventful recovery in 60% SIC          0.100         T
# 49                     uneventful recovery in 60% SIC          0.100         T
# 50  Successful recovery. Took slightly more than 1...          0.100       NaN
# 51  Successful recovery. Took slightly more than 1...          0.100       NaN
# 52         Successful recovery. Relatively uneventful          0.100       NaN
# 53         Successful recovery. Relatively uneventful          0.100       NaN
# 54  last recovery! Quite straightforward. Handled ...          0.100       NaN
# 55  last recovery! Quite straightforward. Handled ...          0.100       NaN
# 56         Successful recovery. Relatively uneventful          0.100       NaN
# 57  Successful recovery. Relatively uneventful. Pi...          0.100       NaN
#
# [58 rows x 35 columns]

# %%
fileList = glob.glob('../../data_directory/array_deployment_gps/T[0-9][0-9][0-9]_full_deployment.csv')

print(fileList)
# Out:
# ['../../data_directory/array_deployment_gps/T016_full_deployment.csv', '../../data_directory/array_deployment_gps/T017_full_deployment.csv', '../../data_directory/array_deployment_gps/T014_full_deployment.csv', '../../data_directory/array_deployment_gps/T015_full_deployment.csv', '../../data_directory/array_deployment_gps/T013_full_deployment.csv', '../../data_directory/array_deployment_gps/T012_full_deployment.csv', '../../data_directory/array_deployment_gps/T011_full_deployment.csv', '../../data_directory/array_deployment_gps/T008_full_deployment.csv', '../../data_directory/array_deployment_gps/T009_full_deployment.csv', '../../data_directory/array_deployment_gps/T004_full_deployment.csv', '../../data_directory/array_deployment_gps/T005_full_deployment.csv', '../../data_directory/array_deployment_gps/T006_full_deployment.csv', '../../data_directory/array_deployment_gps/T007_full_deployment.csv', '../../data_directory/array_deployment_gps/T018_full_deployment.csv', '../../data_directory/array_deployment_gps/T001_full_deployment.csv', '../../data_directory/array_deployment_gps/T019_full_deployment.csv', '../../data_directory/array_deployment_gps/T003_full_deployment.csv', '../../data_directory/array_deployment_gps/T002_full_deployment.csv', '../../data_directory/array_deployment_gps/T029_full_deployment.csv', '../../data_directory/array_deployment_gps/T028_full_deployment.csv', '../../data_directory/array_deployment_gps/T020_full_deployment.csv', '../../data_directory/array_deployment_gps/T022_full_deployment.csv', '../../data_directory/array_deployment_gps/T023_full_deployment.csv', '../../data_directory/array_deployment_gps/T025_full_deployment.csv', '../../data_directory/array_deployment_gps/T024_full_deployment.csv', '../../data_directory/array_deployment_gps/T027_full_deployment.csv', '../../data_directory/array_deployment_gps/T026_full_deployment.csv']

# %%
# Function to read in Iridium Beacon CSV files, parse datetimes, and return slim and usable dataframe
def parse_file(fileName):
    # Get Deployment Name
    deploymentString = re.search(r'T\d{3}', fileName).group()

    # Print String in case of error
    print(deploymentString)

    # Read in Data
    data = pd.read_csv(fileName)
    data.rename(columns={'Asset Name':'assetName',
                         'Data Date (AKDT)':'dateTimeAKDT',
                         ' Latitude':'latitude',
                         ' Longitude':'longitude'}, inplace=True)
    
    # Make Time Datetime Object - two possible formats (slashes-seconds or dashes+seconds)
    formats = ["%Y-%m-%d %H:%M:%S", "%m/%d/%y %H:%M"] #, "%m-%d-%y %H:%M"]
    for fmt in formats:
        try:
            # datetime = data['dateTimeAKDT'].apply(lambda x: dt.strptime(x, fmt))
            datetime = data['dateTimeAKDT'].apply(lambda x: dt.strptime(str(x), fmt) if pd.notnull(x) else pd.NaT)
            # print(datetime)
        except ValueError:
            # Continue to the next format if the current one fails
            continue
    
    data['dateTimeAKDT'] = datetime
    # Select Necessary Data, Sort and Reset Index
    dataSlim = data.dropna(subset=['dateTimeAKDT'])[['dateTimeAKDT', 'latitude', 'longitude']].sort_values(by='dateTimeAKDT').drop_duplicates().reset_index(drop=True)
    dataSlim['deployment'] = deploymentString
    return(dataSlim)

# %%
# computes speed and other summary stats from streamlined dataframes
def compute_speed_metrics(df):
    dataSlim = df
    deploymentString = dataSlim['deployment'].iloc[0]

    # Compute Total Distance Travelled
    lat_deploy = dataSlim['latitude'].iloc[0]
    lat_recover = dataSlim['latitude'].iloc[-1]
    lon_deploy = dataSlim['longitude'].iloc[0]
    lon_recover = dataSlim['longitude'].iloc[-1]
    lats = [lat_deploy, lat_recover]
    lons = [lon_deploy, lon_recover]
    # lats = [dataSlim['latitude'].iloc[0], dataSlim['latitude'].iloc[-1]]
    # lons = [dataSlim['longitude'].iloc[0], dataSlim['longitude'].iloc[-1]]
    total_distance_travelled = gsw.geostrophy.distance(lats, lons) / 1000 # return in km

    # Compute Velocity
    ## difference in time points in seconds
    seconds = dataSlim['dateTimeAKDT'].diff().dt.total_seconds()
    ## difference in time points in meters (use insert to make indexing match time difference)
    meters = np.insert(gsw.geostrophy.distance(dataSlim['longitude'], dataSlim['latitude']), 0, np.nan)
    ## convert to centimeters to make final unit match current measurements
    centimeters = 100*meters
    ## speed in cm/s - done with np.where to prevent inf if seconds data is na
    # speed_cm_s = centimeters / seconds
    speed_cm_s = np.where(seconds != 0, centimeters / seconds, np.nan)

    # Summary Stats
    speedMean = np.nanmean(speed_cm_s)
    speedSd = np.nanstd(speed_cm_s)
    speedMax = np.nanmax(speed_cm_s)
    speedMin = np.nanmin(speed_cm_s)

    # Return as Dataframe
    result_df = pd.DataFrame({
        'deployment':deploymentString,
        'totalDist_km':total_distance_travelled,
        'speedMean_cm_s':speedMean,
        'speedSd':speedSd,
        'speedMax':speedMax,
        'speedMin':speedMin,
        'deployLat':lat_deploy,
        'deployLon':lon_deploy,
        'recoverLat':lat_recover,
        'recoverLon':lon_recover
    })
    return(result_df)

# %%
## T010 is special because we lost the beacon
t010 = pd.read_csv('../../data_directory/array_deployment_gps/T010_full_deployment_spotter.csv')
t010.rename(columns={'Epoch Time':'epochTime',
                            'Latitude (deg)':'latitude',
                            'Longitude (deg)':'longitude'},
                     inplace=True)

t010['deployment'] = 'T010'
t010['dateTimeUTC'] = t010['epochTime'].apply(lambda x: dt.fromtimestamp(x))
t010['dateTimeAKDT'] = t010['dateTimeUTC'] - datetime.timedelta(hours=8)

t010 = t010.loc[:, ['deployment', 'dateTimeAKDT', 'latitude', 'longitude']].sort_values(by='dateTimeAKDT').drop_duplicates().reset_index(drop=True)

t010_speed = compute_speed_metrics(t010)
t010_speed
# Out:
#   deployment  totalDist_km  speedMean_cm_s    speedSd   speedMax  speedMin  \
# 0       T010    220.883103       20.041601  10.438201  42.324341  3.188885
#
#    deployLat  deployLon  recoverLat  recoverLon
# 0   70.41515 -163.56137    70.57455  -161.58075

# %%
fileList
# Out:
# ['../../data_directory/array_deployment_gps/T016_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T017_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T014_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T015_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T013_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T012_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T011_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T008_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T009_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T004_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T005_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T006_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T007_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T018_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T001_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T019_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T003_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T002_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T029_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T028_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T020_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T022_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T023_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T025_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T024_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T027_full_deployment.csv',
#  '../../data_directory/array_deployment_gps/T026_full_deployment.csv']

# %%
speed_metrics_all = pd.concat([compute_speed_metrics(parse_file(file)) for file in fileList])
speed_metrics_all = pd.concat([speed_metrics_all, t010_speed])
# Out:
# T016
# T017
# T014
# T015
# T013
# T012
# T011
# T008
# T009
# T004
# T005
# T006
# T007
# T018
# T001
# T019
# T003
# T002
# T029
# T028
# T020
# T022
# T023
# T025
# T024
# T027
# T026

# %%
speed_metrics_all = speed_metrics_all.sort_values(by='deployment').reset_index(drop=True)
speed_metrics_all
# Out:
#    deployment  totalDist_km  speedMean_cm_s    speedSd   speedMax   speedMin  \
# 0        T001      0.562567       31.059237   0.000000  31.059237  31.059237
# 1        T002     24.977047       13.600728   4.984864  27.091254   2.068243
# 2        T003     54.162838       10.543892   4.772877  22.489893   0.661329
# 3        T004     73.049696       18.423708   4.925776  28.044179   4.142416
# 4        T005    312.071075       24.349386   9.440234  63.691781   0.823508
# 5        T006    147.727778       12.739912   5.552675  23.881294   1.388088
# 6        T007    164.147697       16.801080   8.730653  37.171630   0.749297
# 7        T008    213.825596       14.174455   8.670985  46.525197   1.226236
# 8        T009    269.170252       19.497726   9.792536  43.917596   1.512148
# 9        T010    220.883103       20.041601  10.438201  42.324341   3.188885
# 10       T011     80.663093       12.743031   4.421329  25.748284   0.897606
# 11       T012    147.568741       22.389660   5.362556  33.453461   8.605938
# 12       T013    245.396594       18.452276   7.311848  54.839262   4.354231
# 13       T014     49.436642       11.903013   5.151439  24.506469   2.485383
# 14       T015    180.601693       13.083372   6.048652  48.418325   1.399716
# 15       T016    128.576110       11.901861   5.530164  24.044937   0.586687
# 16       T017     65.549432        8.723474   5.858680  26.684949   0.193767
# 17       T018     59.530746        8.010340   3.612509  14.368024   0.163187
# 18       T019     35.329398       10.300866   3.957456  22.127737   2.152455
# 19       T020    112.954902        9.270432   3.101065  19.047452   0.735221
# 20       T022     24.312927        9.492204   3.916231  28.882548   0.349805
# 21       T023     15.758890        9.444662   4.678558  39.231753   0.683240
# 22       T024    186.016317       12.658524   5.071696  27.147632   2.706853
# 23       T025    166.459934       12.549527   5.166190  30.751824   4.317589
# 24       T026     72.407189       12.304173   6.114813  28.947414   0.323177
# 25       T027     17.311008        6.048752   2.663425  11.266453   1.036231
# 26       T028    198.709023       19.911535   4.657451  33.897296   8.721075
# 27       T029    107.594386       14.338985   6.464197  32.154577   0.344676
#
#     deployLat   deployLon  recoverLat  recoverLon
# 0   70.885031 -161.379777   70.884765 -161.374724
# 1   70.698394 -165.534161   70.617849 -165.744797
# 2   71.282081 -164.579399   71.198278 -164.099031
# 3   70.409049 -163.530099   70.376165 -162.873902
# 4   70.808548 -163.268809   70.779194 -160.462425
# 5   71.182970 -163.045772   71.080765 -161.720800
# 6   71.400898 -164.393234   71.226468 -162.926538
# 7   71.062242 -164.988256   70.914635 -163.070519
# 8   70.695359 -165.528302   70.673890 -163.107684
# 9   70.415150 -163.561370   70.574550 -161.580750
# 10  71.586153 -163.633923   71.379482 -162.936029
# 11  71.395582 -164.397367   71.253086 -163.077318
# 12  71.057671 -164.980230   70.867428 -162.780905
# 13  71.659867 -164.046232   71.312532 -163.752461
# 14  71.531714 -164.236980   71.175774 -162.649026
# 15  71.194185 -164.798656   70.937905 -163.668952
# 16  70.942948 -165.184357   70.800351 -164.611158
# 17  70.698824 -165.523144   70.566016 -165.003406
# 18  71.664355 -163.980410   71.344829 -164.061585
# 19  71.307771 -164.586461   71.071351 -163.596404
# 20  70.699402 -165.519519   70.504834 -165.630429
# 21  71.656609 -164.031243   71.509699 -164.042873
# 22  71.419931 -164.406989   71.275145 -162.739878
# 23  71.191320 -164.779408   71.115511 -163.284173
# 24  70.942315 -165.191717   70.964159 -164.540885
# 25  71.663690 -163.997126   71.519709 -164.068365
# 26  71.183285 -164.810801   71.030420 -163.029814
# 27  70.942422 -165.188456   70.858963 -164.224191

# %%
speed_metrics_all.to_csv('../../data_directory/metadata/speed_metrics_all_array_deployments.csv')

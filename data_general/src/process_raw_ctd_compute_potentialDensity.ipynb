# %% [markdown]
# This Python script reads in all the quality controlled csv files for each cast, computes GSW metrics and potential density, and saves to one new csv (final_qc_CTD_data_all.csv)

# %%
import pandas as pd
import numpy as np
import gsw
from glob import glob
# import re
import csv

# %%
source_dir = '../data_ctd_raw/'
save_dir = '../processed_data/'

# %%
fileList = glob(source_dir + 'SKQ202310S_ct1/*.csv')

print(fileList)
# Out:
# ['../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s098c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s287c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s126c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s278c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s005c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s032c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s173c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s144c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s067c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s050c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s190c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s084c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s253c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s264c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s019c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s231c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s206c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s158c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s149c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s217c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s220c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s275c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s008c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s242c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s095c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s181c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s041c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s076c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s155c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s162c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s023c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s269c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s014c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s137c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s100c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s296c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s089c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s184c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s090c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s225c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s058c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s212c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s029c02_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s247c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s270c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s119c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s293c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s198c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s167c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s150c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s073c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s239c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s044c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s105c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s132c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s011c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s026c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s037c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s123c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s114c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s228c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s055c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s062c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s141c01_ct1.csv', '../data_ctd_raw/SKQ202310S_ct1/SK ...

# %%
def read_cast_metadata(filename_string):
    # make empty list to store cast metadata:
    data_strings = []
    # add the filename of the cast file to the cast metadata list
    data_strings.append(f'FILE = {filename_string}')

    # Open the CSV file for the cast
    with open(filename_string, 'r') as file:
    # Create a CSV reader object
        reader = csv.reader(file)
    
    # Read the cast metadata lines (3-10) and append to the data_strings list
        for i, row in enumerate(reader):
            if i >= 3 and i <= 10:
                data_strings.append(row[0].strip()) # .strip() removes whitespace
            elif 1 > 10:
                break
    
    # Split each data string into key and value
    split_data = [item.split(' = ') for item in data_strings]

    # Create DataFrame
    meta_df_2col = pd.DataFrame(split_data, columns=['Key', 'Value'])

    # # Strip Whitespace
    # meta_df_2col.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # Transpose the DataFrame
    meta_df= meta_df_2col.set_index('Key').T

    return(meta_df)

# %%
def read_cast_data(filename_string):
    # The first part of this function generates column names for the dataframe, the second reads in the data
    # Variable Names are in the 11th row, Units are in the 12th, and data is row 13 on
    # We will read in varnames and units, combine the strings, then use these new strings as colnames for the data

    # variable names are in the 11th row
    varnames = pd.read_csv(filename_string, header=None, skiprows=11, nrows=1)

    # units for each variable are in the 12th row
    units = pd.read_csv(filename_string, header=None, skiprows=12, nrows=1)

    # create empty list to store combined varname and unit string
    column_names = []
    # combine the string
    for varnames, units in zip(varnames.values[0], units.values[0]):
    # if there is a unit, combine with varname to make new colname
        if pd.notna(units):
            column_names.append(str(varnames) + '_' + str(units))
    # if no unit, varname is colname
        else:
            column_names.append(str(varnames))

    # Here we read in the data
    # Read the CSV file skipping the first 13 rows, set the column names using list generated above
    data_df = pd.read_csv(filename_string, header=None, skiprows=13, names = column_names)

    return(data_df)

# %%
datadf = read_cast_data(fileList[2])
metadf = read_cast_metadata(fileList[2])

datadf.assign(**metadf.iloc[0])
# Out:
#    CTDPRS_DBAR  CTDPRS_FLAG_W  CTDDEPTH_METERS  CTDDEPTH_FLAG_W  \
# 0        2.000            2.0            1.980              2.0
# 1        3.000            2.0            2.969              2.0
# 2        4.000            2.0            3.959              2.0
# 3        5.000            2.0            4.949              2.0
# 4        6.000            2.0            5.939              2.0
# 5        7.000            2.0            6.929              2.0
# 6        8.000            2.0            7.918              2.0
# 7        9.000            2.0            8.908              2.0
# 8       10.000            2.0            9.898              2.0
# 9       11.000            2.0           10.888              2.0
# 10      12.000            2.0           11.878              2.0
# 11      13.000            2.0           12.867              2.0
# 12      14.000            2.0           13.857              2.0
# 13      15.000            2.0           14.847              2.0
# 14      16.000            2.0           15.836              2.0
# 15      17.000            2.0           16.826              2.0
# 16      18.000            2.0           17.816              2.0
# 17      19.000            2.0           18.806              2.0
# 18      20.000            2.0           19.796              2.0
# 19      21.000            2.0           20.785              2.0
# 20      22.000            2.0           21.775              2.0
# 21      23.000            2.0           22.765              2.0
# 22      24.000            2.0           23.754              2.0
# 23      25.000            2.0           24.744              2.0
# 24      26.000            2.0           25.734              2.0
# 25      27.000            2.0           26.724              2.0
# 26      28.000            2.0           27.713              2.0
# 27      29.000            2.0           28.703              2.0
# 28      30.000            2.0           29.693              2.0
# 29      31.000            2.0           30.682              2.0
# 30      32.000            2.0           31.672              2.0
# 31      33.000            2.0           32.662              2.0
# 32      34.000            2.0           33.651              2.0
# 33      35.000            2.0           34.641              2.0
# 34      36.000            2.0           35.631              2.0
# 35      37.000            2.0           36.620              2.0
# 36      38.000            2.0           37.610              2.0
# 37      39.000            2.0           38.599              2.0
# 38      40.000            2.0           39.589              2.0
# 39      41.000            2.0           40.579              2.0
# 40      42.000            2.0           41.568              2.0
# 41      43.000            2.0           42.558              2.0
# 42    END_DATA            NaN              NaN              NaN
#
#     CTDTMP_ITS-90  CTDTMP_FLAG_W  CTDTMP2_ITS-90  CTDTMP2_FLAG_W  CTDSAL_PSU  \
# 0         -0.5160            2.0         -0.5160             2.0     32.1543
# 1         -0.5321            2.0         -0.5396             2.0     32.1936
# 2         -0.7986            2.0         -0.8102             2.0     32.2448
# 3         -1.0970            2.0         -1.1035             2.0     32.2713
# 4         -1.2495            2.0         -1.2525             2.0     32.2899
# 5         -1.3086            2.0         -1.3100             2.0     32.3003
# 6         -1.3682            2.0         -1.3680             2.0     32.3143
# 7         -1.4654            2.0         -1.4659             2.0     32.3348
# 8         -1.4884            2.0         -1.4880             2.0     32.3519
# 9         -1.5353            2.0         -1.5353             2.0     32.3810
# 10        -1.5766            2.0         -1.5761             2.0     32.4100
# 11        -1.6041            2.0         -1.6033             2.0     32.4523
# 12        -1.6126            2.0         -1.6118             2.0     32.4817
# 13        -1.6137            2.0         -1.6127             2.0     32.5080
# 14        -1.6266            2.0         -1.6256             2.0     32.5448
# 15        -1.6333            2.0         -1.6324             2.0     32.5790
# 16        -1.6511            2.0         -1.6498             2.0     32.6092
# 17        -1.6650            2.0         -1.6639             2.0     32.6500
# 18        -1.6841            2.0         -1.6830             2.0     32.7077
# 19        -1.7058            2.0         -1.7047             2.0     32.7565
# 20        -1.7114            2.0         -1.7103             2.0     32.7931
# 21        -1.7038            2.0         -1.7029             2.0     32.8288
# 22        -1.7030            2.0         -1.7021             2.0     32.8350
# 23        -1.7045            2.0         -1.7036             2.0     32.8426
# 24        -1.7053            2.0         -1.7044             2.0     32.8449
# 25        -1.7053            2.0         -1.7044             2.0     32.8454
# 26        -1.7054            2.0         -1.7045             2.0     32.8456
# 27        -1.7053            2.0         -1.7044             2.0     32.8464
# 28        -1.7054            2.0         -1.7045             2.0     32.8482
# 29        -1.7056            2.0         -1.7047             2.0     32.8498
# 30        -1.7056            2.0         -1.7047             2.0     32.8508
# 31        -1.7055            2.0         -1.7046             2.0     32.8516
# 32        -1.7056            2.0         -1.7047             2.0     32.8518
# 33        -1.7057            2.0         -1.7048             2.0     32.8516
# 34        -1.7056            2.0         -1.7047             2.0     32.8520
# 35        -1.7056            2.0         -1.7047             2.0     32.8524
# 36        -1.7056            2.0         -1.7047             2.0     32.8523
# 37        -1.7057            2.0         -1.7048             2.0     32.8531
# 38        -1.7058            2.0         -1.7048             2.0     32.8557
# 39        -1.7057            2.0         -1.7047             2.0     32.8544
# 40        -1.7057            2.0         -1.7047             2.0     32.8529
# 41        -1.7056            2.0         -1.7046             2.0     32.8529
# 42            NaN            NaN             NaN             NaN         NaN
#
#     CTDSAL_FLAG_W  ...  SPAR_FLAG_W  \
# 0             2.0  ...          5.0
# 1             2.0  ...          5.0
# 2             2.0  ...          5.0
# 3             2.0  ...          5.0
# 4             2.0  ...          5.0
# 5             2.0  ...          5.0
# 6             2.0  ...          5.0
# 7             2.0  ...          5.0
# 8             2.0  ...          5.0
# 9             2.0  ...          5.0
# 10            2.0  ...          5.0
# 11            2.0  ...          5.0
# 12            2.0  ...          5.0
# 13            2.0  ...          5.0
# 14            2.0  ...          5.0
# 15            2.0  ...          5.0
# 16            2.0  ...          5.0
# 17            2.0  ...          5.0
# 18            2.0  ...          5.0
# 19            2.0  ...          5.0
# 20            2.0  ...          5.0
# 21            2.0  ...          5.0
# 22            2.0  ...          5.0
# 23            2.0  ...          5.0
# 24            2.0  ...          5.0
# 25            2.0  ...          5.0
# 26            2.0  ...          5.0
# 27            2.0  ...          5.0
# 28            2.0  ...          5.0
# 29            2.0  ...          5.0
# 30            2.0  ...          5.0
# 31            2.0  ...          5.0
# 32            2.0  ...          5.0
# 33            2.0  ...          5.0
# 34            2.0  ...          5.0
# 35            2.0  ...          5.0
# 36            2.0  ...          5.0
# 37            2.0  ...          5.0
# 38            2.0  ...          5.0
# 39            2.0  ...          5.0
# 40            2.0  ...          5.0
# 41            2.0  ...          5.0
# 42            NaN  ...          NaN
#
#                                                  FILE   SECT_ID  STNNBR  \
# 0   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 1   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 2   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 3   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 4   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 5   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 6   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 7   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 8   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 9   ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 10  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 11  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 12  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 13  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 14  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 15  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 16  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 17  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 18  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 19  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 20  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 21  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 22  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 23  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 24  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 25  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 26  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 27  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 28  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 29  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 30  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 31  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 32  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 33  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 34  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 35  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 36  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 37  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 38  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 39  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 40  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 41  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
# 42  ../data_ctd_raw/SKQ202310S_ct1/SKQ202310S_s111...  HRE4-5.5     111
#
#     CASTNO      DATE  TIME  LATITUDE  LONGITUDE  DEPTH
# 0        1  20230710  0253   70.8783   -163.275     45
# 1        1  20230710  0253   70.8783   -163.275     45
# 2        1  20230710  0253   70.8783   -163.275     45
# 3        1  20230710  0253   70.8783   -163.275     45
# 4        1  20230710  0253   70.8783   -163.275     45
# 5        1  20230710  0253   70.8783   -163.275     45
# 6        1  20230710  0253   70.8783   -163.275     45
# 7        1  20230710  0253   70.8783   -163.275     45
# 8        1  20230710  0253   70.8783   -163.275     45
# 9        1  20230710  0253   70.8783   -163.275     45
# 10       1  20230710  0253   70.8783   -163.275     45
# 11       1  20230710  0253   70.8783   -163.275     45
# 12       1  20230710  0253   70.8783   -163.275     45
# 13       1  20230710  0253   70.8783   -163.275     45
# 14       1  20230710  0253   70.8783   -163.275     45
# 15       1  20230710  0253   70.8783   -163.275     45
# 16       1  20230710  0253   70.8783   -163.275     45
# 17       1  20230710  0253   70.8783   -163.275     45
# 18       1  20230710  0253   70.8783   -163.275     45
# 19       1  20230710  0253   70.8783   -163.275     45
# 20       1  20230710  0253   70.8783   -163.275     45
# 21       1  20230710  0253   70.8783   -163.275     45
# 22       1  20230710  0253   70.8783   -163.275     45
# 23       1  20230710  0253   70.8783   -163.275     45
# 24       1  20230710  0253   70.8783   -163.275     45
# 25       1  20230710  0253   70.8783   -163.275     45
# 26       1  20230710  0253   70.8783   -163.275     45
# 27       1  20230710  0253   70.8783   -163.275     45
# 28       1  20230710  0253   70.8783   -163.275     45
# 29       1  20230710  0253   70.8783   -163.275     45
# 30       1  20230710  0253   70.8783   -163.275     45
# 31       1  20230710  0253   70.8783   -163.275     45
# 32       1  20230710  0253   70.8783   -163.275     45
# 33       1  20230710  0253   70.8783   -163.275     45
# 34       1  20230710  0253   70.8783   -163.275     45
# 35       1  20230710  0253   70.8783   -163.275     45
# 36       1  20230710  0253   70.8783   -163.275     45
# 37       1  20230710  0253   70.8783   -163.275     45
# 38       1  20230710  0253   70.8783   -163.275     45
# 39       1  20230710  0253   70.8783   -163.275     45
# 40       1  20230710  0253   70.8783   -163.275     45
# 41       1  20230710  0253   70.8783   -163.275     45
# 42       1  20230710  0253   70.8783   -163.275     45
#
# [43 rows x 33 columns]

# %%
# create empty list to store dataframe from each cast
list_of_cast_dataframes = []
# for loop generates a dataframe for each cast, then appends to the list
for filename in fileList:
    # Read in Metadata using function
    metadata = read_cast_metadata(filename)
    # Read in Data using function
    data = read_cast_data(filename)
    # Data and Metadata shapes are incompatible, need to expand metadata so each dataframe has same number of rows
    # this will expand the metadata dataframe, duplicating the data to match the shape of the data dataframe
    metadata_expanded = pd.concat([metadata] * data.shape[0], ignore_index=True)
    # metadata_expanded = metadata.loc[data.index].reset_index(drop=True)
    # combine the data and metadata
    cast_dataframe = pd.concat([metadata_expanded, data], axis=1)
    # The concat caused some reshaping issues
    # Assign command allows us to assign the metadata variables to every row of the data dataframe
    # cast_dataframe = data.assign(**metadata.iloc[0])

    # One useless row at end of each file - must cut
    cast_dataframe.drop(cast_dataframe[cast_dataframe['CTDPRS_DBAR'] == 'END_DATA'].index, inplace = True)
    # append to list
    list_of_cast_dataframes.append(cast_dataframe)

# %%
# list_of_cast_dataframes[0]

# %%
# concatenate all the cast dataframes
ctd = pd.concat(list_of_cast_dataframes)

# Make STNNBR an int, CTDPRS_DBAR swap to numeric - both were sorting lexically
ctd['STNNBR'] = ctd['STNNBR'].astype(int)
ctd['CTDPRS_DBAR'] = pd.to_numeric(ctd['CTDPRS_DBAR'])

# after concat and drop, sort values by station then by pressure(depth), then reset indexing
ctd = ctd.sort_values(by = ['STNNBR', 'CTDPRS_DBAR'], ignore_index=True)

# %%
## Add SECTION and LINE variables using regex

# LINE is all letters before the first number in SECT_ID
ctd['LINE'] = ctd['SECT_ID'].str.extract(r'([a-zA-Z]+)(?=\d)', expand=False)

# SECTION is all characters before the dash, or, if there is no dash, all characters in SECT_ID
ctd['SECTION'] = ctd['SECT_ID'].str.split('-', expand=True)[0]

# check that all lines appear:
# ctd['LINE'].drop_duplicates()

# check that all sections appear:
# for i in ctd['SECTION'].drop_duplicates():
#     print(i)

# %%
# Convert Values to floats for use with GSW
ctd['CTDPRS_DBAR'] = ctd['CTDPRS_DBAR'].astype(float)
ctd['LONGITUDE'] = ctd['LONGITUDE'].astype(float)
ctd['LATITUDE'] = ctd['LATITUDE'].astype(float)
ctd['STNNBR'] = ctd['STNNBR'].astype(float)

# %%
# GSW (Gibbs SeaWater) Conversions Necessary to pull out Potential Density

ctd['SA_sal_gperkg'] = gsw.SA_from_SP(ctd['CTDSAL_PSU'], ctd['CTDPRS_DBAR'], ctd['LONGITUDE'], ctd['LATITUDE'])
ctd['CT_temp_its90'] = gsw.CT_from_t(ctd['SA_sal_gperkg'], ctd['CTDTMP_ITS-90'], ctd['CTDPRS_DBAR'])
ctd['SIGMA0_kgperm3'] = gsw.density.sigma0(ctd['SA_sal_gperkg'], ctd['CT_temp_its90'])
# ctd['rho_ref'] = 10
# ctd['poDensity_kgperm3'] = gsw.rho(ctd['SA_sal_gperkg'], ctd['CT_temp_its90'], ctd['rho_ref'])
# Coriolis parameter here = 2*OMEGA*np.sin(np.radians(latitude))
ctd['CORIOLIS'] = gsw.geostrophy.f(ctd['LATITUDE'])

# %%
# Write to CSV
ctd.to_csv(save_dir + 'final_qc_CTD_data.csv', index=False)
